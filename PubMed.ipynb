# %%
# !pip install requests pandas
# Out:
# Requirement already satisfied: requests in c:\users\prasa\anaconda3\lib\site-packages (2.31.0)
# Requirement already satisfied: pandas in c:\users\prasa\anaconda3\lib\site-packages (2.0.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\prasa\anaconda3\lib\site-packages (from requests) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\prasa\anaconda3\lib\site-packages (from requests) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\prasa\anaconda3\lib\site-packages (from requests) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\prasa\anaconda3\lib\site-packages (from requests) (2023.7.22)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\prasa\anaconda3\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\prasa\anaconda3\lib\site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\prasa\anaconda3\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: numpy>=1.21.0 in c:\users\prasa\anaconda3\lib\site-packages (from pandas) (1.24.3)
# Requirement already satisfied: six>=1.5 in c:\users\prasa\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)

# %%
import requests
import pandas as pd

# %%
def fetch_articles(query):
    base_url = "https://eutils.ncbi.nlm.nih.gov/entrez/eutils/"
    search_url = f"{base_url}esearch.fcgi?db=pubmed&term={query}&retmode=json"
    response = requests.get(search_url)
    if response.status_code == 200:
        data = response.json()
        return data['esearchresult']['idlist']
    else:
        print("Error fetching articles:", response.status_code)
        return []

# Example usage
query = "biotech research"
article_ids = fetch_articles(query)
print("Fetched PubMed IDs:", article_ids)
# Out:
# Fetched PubMed IDs: ['40051483', '40051141', '40050970', '40050842', '40050768', '40050521', '40050434', '40050409', '40049766', '40049403', '40049207', '40049206', '40049185', '40048691', '40047735', '40047724', '40047259', '40046028', '40046014', '40045789']

# %%
def fetch_article_details(article_ids):
    base_url = "https://eutils.ncbi.nlm.nih.gov/entrez/eutils/"
    fetch_url = f"{base_url}esummary.fcgi?db=pubmed&id={','.join(article_ids)}&retmode=json"
    response = requests.get(fetch_url)
    if response.status_code == 200:
        return response.json()
    else:
        print("Error fetching article details:", response.status_code)
        return {}

# Example usage
article_details = fetch_article_details(article_ids)
print("Article Details:", article_details)
# Out:
# Article Details: {'header': {'type': 'esummary', 'version': '0.3'}, 'result': {'uids': ['40051483', '40051141', '40050970', '40050842', '40050768', '40050521', '40050434', '40050409', '40049766', '40049403', '40049207', '40049206', '40049185', '40048691', '40047735', '40047724', '40047259', '40046028', '40046014', '40045789'], '40051483': {'uid': '40051483', 'pubdate': '2024 Dec', 'epubdate': '2024 Dec 2', 'source': 'Psychedelic Med (New Rochelle)', 'authors': [{'name': 'Haggarty C', 'authtype': 'Author', 'clusterid': ''}, {'name': 'Molla H', 'authtype': 'Author', 'clusterid': ''}, {'name': 'Glazer J', 'authtype': 'Author', 'clusterid': ''}, {'name': 'Tare I', 'authtype': 'Author', 'clusterid': ''}, {'name': 'Rains A', 'authtype': 'Author', 'clusterid': ''}, {'name': 'de Wit H', 'authtype': 'Author', 'clusterid': ''}, {'name': 'Lee R', 'authtype': 'Author', 'clusterid': ''}], 'lastauthor': 'Lee R', 'title': 'Low-Dose LSD Alters Early and Late Event-Related Potentials to Emotional Faces.', 'sorttitle': 'low dose lsd alters early and late event related potentials to emotional faces', 'volume': '2', 'issue': '4', 'pages': '210-220', 'lang': ['eng'], 'nlmuniqueid': '9918610585506676', 'issn': '2831-4425', 'essn': '2831-4433', 'pubtype': ['Journal Article'], 'recordstatus': 'PubMed', 'pubstatus': '258', 'articleids': [{'idtype': 'pubmed', 'idtypen': 1, 'value': '40051483'}, {'idtype': 'pmc', 'idtypen': 8, 'value': 'PMC11658383'}, {'idtype': 'pmcid', 'idtypen': 5, 'value': 'pmc-id: PMC11658383;embargo-date: 2025/12/02;'}, {'idtype': 'doi', 'idtypen': 3, 'value': '10.1089/psymed.2024.0005'}, {'idtype': 'pii', 'idtypen': 4, 'value': '10.1089/psymed.2024.0005'}], 'history': [{'pubstatus': 'medline', 'date': '2025/03/07 06:22'}, {'pubstatus': 'pubmed', 'date': '2025/03/07 06:21'}, {'pubstatus': 'pmc-release', 'date': '2025/12/02 00:00'}, {'pubstatus': 'entrez', 'date': '2025/03/07 04:15'}], 'references': [], 'attributes': ['Has Abstract'], 'pmcrefcount': 58, 'fulljournalname': 'Psychedelic medicine (New Rochelle, N.Y.)', 'elocationid': 'doi: 10.1089/psymed.2024.0005', 'doctype': 'citation', 'srccontriblist': [], 'booktitle': '', 'medium': '', 'edition': '', 'publisherlocation': '', 'publishername': '', 'srcdate': '', 'reportnumber': '', 'availablefromurl': '', 'locationlabel': '', 'doccontriblist': [], 'docdate': '', 'bookname': '', 'chapter': '', 'sortpubdate': '2024/12/02 00:00', 'sortfirstauthor': 'Haggarty C', 'vernaculartitle': ''}, '40051141': {'uid': '40051141', 'pubdate': '2025 Mar', 'epubdate': '', 'source': 'Plant J', 'authors': [{'name': 'Barrios A', 'authtype': 'Author', 'clusterid': ''}, {'name': 'Gaggion N', 'authtype': 'Author', 'clusterid': ''}, {'name': 'Mansilla N', 'authtype': 'Author', 'clusterid': ''}, {'name': 'Blein T', 'authtype': 'Author', 'clusterid': ''}, {'name': 'Sorin C', 'authtype': 'Author', 'clusterid': ''}, {'name': 'Lucero L', 'authtype': 'Author', 'clusterid': ''}, {'name': 'Ferrante E', 'authtype': 'Author', 'clusterid': ''}, {'name': 'Crespi M', 'authtype': 'Author', 'clusterid': ''}, {'name': 'Ariel F', 'authtype': 'Author', 'clusterid': ''}], 'lastauthor': 'Ariel F', 'title': 'The transcription factor NF-YA10 determines the area explored by Arabidopsis thaliana roots and directly regulates LAZY genes.', 'sorttitle': 'transcription factor nf ya10 determines the area explored by arabidopsis thaliana roots and directly regulates lazy genes', 'volume': '121', 'issue': '5', 'pages': 'e70016', 'lang': ['eng'], 'nlmuniqueid': '9207397', 'issn': '0960-7412', 'essn': '1365-313X', 'pubtype': ['Journal Article'], 'recordstatus': 'PubMed - indexed for MEDLINE', 'pubstatus': '4', 'articleids': [{'idtype': 'pubmed', 'idtypen': 1, 'value': '40051141'}, {'idtype': 'doi', 'idtypen': 3, 'value': '10.1111/tpj.70016'}], 'history': [{'pubstatus': 'medline', 'date': '2025/03/07 06:22'}, {'pubstatus': 'pubmed', 'date': '2025/03/07 06:21'}, {'pubstatus': 'received', 'date': '2023/12/25 00:00'}, {'pubstatus': 'accepted',  ...

# %%
def filter_authors(authors):
    company_keywords = ["Pharma", "Biotech", "Inc.", "LLC"]
    company_authors = []
    for author in authors:
        if any(keyword in author.get('affiliation', '') for keyword in company_keywords):
            company_authors.append(author)
    return company_authors

# %%
def save_to_csv(data, filename="output.csv"):
    df = pd.DataFrame(data)
    df.to_csv(filename, index=False)
    print(f"Data saved to {filename}")

# Example dataset for testing
sample_data = [
    {"PubMed ID": "12345678", "Title": "Innovative Biotech Research", 
     "Publication Date": "2025-01-15", "Author Affiliation": "BioPharma Inc., New York, USA"}
]
save_to_csv(sample_data)
# Out:
# Data saved to output.csv
